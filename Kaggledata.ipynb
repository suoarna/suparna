# %%
import pandas as pd
df= pd.read_csv('data.csv')
new_df= df.dropna()
print(new_df.to_string())
# Out:
#                             Country ISO_Code  Year  Electricity_Access_Percent       Entity_Type
# 0                           Albania      ALB  2018                       94.09           Country
# 1                           Albania      ALB  2019                       97.71           Country
# 2                           Andorra      AND  2016                      100.00           Country
# 3                           Andorra      AND  2017                      100.00           Country
# 4                           Andorra      AND  2018                      100.00           Country
# 5                           Andorra      AND  2019                      100.00           Country
# 6                            Angola      AGO  2016                       22.35           Country
# 7               Antigua and Barbuda      ATG  2010                      100.00           Country
# 8               Antigua and Barbuda      ATG  2017                      100.00           Country
# ...

# %%
import pandas as pd
df= pd.read_csv('data.csv')
df.dropna(inplace= True)
print(df.to_string())
# Out:
#                             Country ISO_Code  Year  Electricity_Access_Percent       Entity_Type
# 0                           Albania      ALB  2018                       94.09           Country
# 1                           Albania      ALB  2019                       97.71           Country
# 2                           Andorra      AND  2016                      100.00           Country
# 3                           Andorra      AND  2017                      100.00           Country
# 4                           Andorra      AND  2018                      100.00           Country
# 5                           Andorra      AND  2019                      100.00           Country
# 6                            Angola      AGO  2016                       22.35           Country
# 7               Antigua and Barbuda      ATG  2010                      100.00           Country
# 8               Antigua and Barbuda      ATG  2017                      100.00           Country
# ...

# %%
import pandas as pd
df= pd.read_csv('data.csv')
df.loc[196, 'Entity_Type']= 'Country'
df.loc[197, 'Entity_Type']= 'Country'
df.loc[198, 'Entity_Type']= 'Country'
df.loc[199, 'Entity_Type']= 'Country'
df.loc[200, 'Entity_Type']= 'Country'
df.loc[201, 'Entity_Type']= 'Country'
df.loc[154, 'Entity_Type']= 'Country'
df.loc[155, 'Entity_Type']= 'Country'
df.loc[156, 'Entity_Type']= 'Country'
df.loc[157, 'Entity_Type']= 'Country'
df.loc[158, 'Entity_Type']= 'Country'
df.loc[159, 'Entity_Type']= 'Country'
df.loc[160, 'Entity_Type']= 'Country'
df.loc[161, 'Entity_Type']= 'Country'
df.loc[162, 'Entity_Type']= 'Country'
df.loc[277, 'Entity_Type']= 'Country'
df.loc[278, 'Entity_Type']= 'Country'
df.loc[279, 'Entity_Type']= 'Country'
df.loc[280, 'Entity_Type']= 'Country'
df.loc[281, 'Entity_Type']= 'Country'
df.loc[282, 'Entity_Type']= 'Country'
df.loc[283, 'Entity_Type']= 'Country'
df.loc[284, 'Entity_Type']= 'Country'
df.loc[285, 'Entity_Type']= 'Country'
df.loc[391, 'Entity_Type']= 'Country'
df.loc[392, 'Entity_Type']= 'Country'
df.loc[393, 'Entity_Type']= 'Country'
df.loc[394, 'Entity_Type']= 'Country'
df.loc[395, 'Entity_Type']= 'Country'
df.loc[396, 'Entity_Type']= 'Country'
df.loc[397, 'Entity_Type']= 'Country'
df.loc[398, 'Entity_Type']= 'Country'
df.loc[399, 'Entity_Type']= 'Country'
df.loc[400, 'Entity_Type']= 'Country'
df.loc[409, 'Entity_Type']= 'Country'
df.loc[410, 'Entity_Type']= 'Country'
df.loc[411, 'Entity_Type']= 'Country'
df.loc[412, 'Entity_Type']= 'Country'
df.loc[413, 'Entity_Type']= 'Country'
df.loc[414, 'Entity_Type']= 'Country'
df.loc[415, 'Entity_Type']= 'Country'
df.loc[416, 'Entity_Type']= 'Country'
df.loc[417, 'Entity_Type']= 'Country'
df.loc[418, 'Entity_Type']= 'Country'
df.loc[419, 'Entity_Type']= 'Country'
df.loc[420, 'Entity_Type']= 'Country'
df.loc[638, 'Entity_Type']= 'Country'
df.loc[639, 'Entity_Type']= 'Country'
df.loc[640, 'Entity_Type']= 'Country'
df.loc[641, 'Entity_Type']= 'Country'
df.loc[642, 'Entity_Type']= 'Country'
df.loc[643, 'Entity_Type']= 'Country'
df.loc[644, 'Entity_Type']= 'Country'
df.loc[645, 'Entity_Type']= 'Country'
df.loc[646, 'Entity_Type']= 'Country'
df.loc[680, 'Entity_Type']= 'Country'
df.loc[681, 'Entity_Type']= 'Country'
df.loc[682, 'Entity_Type']= 'Country'
df.loc[683, 'Entity_Type']= 'Country'
df.loc[684, 'Entity_Type']= 'Country'
df.loc[742, 'Entity_Type']= 'Country'
df.loc[743, 'Entity_Type']= 'Country'
df.loc[744, 'Entity_Type']= 'Country'
df.loc[745, 'Entity_Type']= 'Country'
df.loc[746, 'Entity_Type']= 'Country'
df.loc[747, 'Entity_Type']= 'Country'
df.loc[748, 'Entity_Type']= 'Country'
df.loc[749, 'Entity_Type']= 'Country'
df.loc[750, 'Entity_Type']= 'Country'
df.drop_duplicates(inplace= True)
print(df.to_string())
# Out:
#                             Country ISO_Code  Year  Electricity_Access_Percent       Entity_Type
# 0                           Albania      ALB  2018                       94.09           Country
# 1                           Albania      ALB  2019                       97.71           Country
# 2                           Andorra      AND  2016                      100.00           Country
# 3                           Andorra      AND  2017                      100.00           Country
# 4                           Andorra      AND  2018                      100.00           Country
# 5                           Andorra      AND  2019                      100.00           Country
# 6                            Angola      AGO  2016                       22.35           Country
# 7               Antigua and Barbuda      ATG  2010                      100.00           Country
# 8               Antigua and Barbuda      ATG  2017                      100.00           Country
# ...

# %%
import pandas as pd
df= pd.read_csv('data.csv')
df.loc[df["Entity_Type"]== "Region/Aggregate","Entity_Type"]="Country"
print(df.to_string())
# Out:
#                             Country ISO_Code  Year  Electricity_Access_Percent Entity_Type
# 0                           Albania      ALB  2018                       94.09     Country
# 1                           Albania      ALB  2019                       97.71     Country
# 2                           Andorra      AND  2016                      100.00     Country
# 3                           Andorra      AND  2017                      100.00     Country
# 4                           Andorra      AND  2018                      100.00     Country
# 5                           Andorra      AND  2019                      100.00     Country
# 6                            Angola      AGO  2016                       22.35     Country
# 7               Antigua and Barbuda      ATG  2010                      100.00     Country
# 8               Antigua and Barbuda      ATG  2017                      100.00     Country
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv('data.csv')
df.plot()
# Out:
# <Axes: >

# %%
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv('data.csv')
df.plot(kind='scatter',x= 'Country',y= 'Year')
# Out:
# <Axes: xlabel='Country', ylabel='Year'>
